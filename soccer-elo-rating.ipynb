# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
# import data
fixtures = pd.read_csv('fixtures.csv')

conditions = [
    fixtures['localteam_score'] > fixtures['visitorteam_score'],
    fixtures['visitorteam_score'] > fixtures['localteam_score'],
    fixtures['localteam_score'] == fixtures['visitorteam_score']
]
choices = [ 1, 0, 0.5 ]
fixtures['outcome'] = np.select(conditions, choices)

# %%
# we can use champions league to test; 
fixtures = fixtures[np.isnan(fixtures['localteam_id']) == False]
fixtures['localteam_id'] = fixtures['localteam_id'].apply(np.int)
fixtures = fixtures[fixtures['league_name'] == 'Champions League']

# %%
#rank fixtures played by each team
localteam_fixtures = fixtures[['localteam_id', 'fixture_id', 'starting_datetime']] \
                        .rename(index=str, columns={'localteam_id': 'team_id'})
visitorteam_fixtures = fixtures[['visitorteam_id', 'fixture_id', 'starting_datetime']] \
                        .rename(index=str, columns={'visitorteam_id': 'team_id'})
                          
frames = [localteam_fixtures, visitorteam_fixtures]
combined_fixtures = pd.concat(frames).reset_index()

combined_fixtures['fixture_order'] = combined_fixtures.groupby('team_id')['starting_datetime'].rank(ascending=True, method='min')
combined_fixtures = combined_fixtures.sort_values(['team_id','fixture_order'])
combined_fixtures['next_fixture'] = combined_fixtures.groupby('team_id')['fixture_id'].shift(-1)

# %%
fixtures = pd.merge(fixtures, combined_fixtures[['fixture_order', 'fixture_id', 'team_id', 'next_fixture']],\
                    how='left', left_on=['localteam_id','fixture_id'], right_on = ['team_id','fixture_id'])\
                .drop(['team_id'], axis=1)\
                .rename(index=str, columns={'fixture_order': 'localteam_order', 'next_fixture': 'localteam_next'})

fixtures = pd.merge(fixtures, combined_fixtures[['fixture_order', 'fixture_id', 'team_id', 'next_fixture']],\
            how='left', left_on=['visitorteam_id','fixture_id'], right_on = ['team_id','fixture_id'])\
        .drop(['team_id'], axis=1)\
        .rename(index=str, columns={'fixture_order': 'visitorteam_order', 'next_fixture': 'visitorteam_next'})

# %%
fixtures_f = fixtures

#fixtures_f.drop('cur_team_r', axis=1, inplace=True)
#fixtures_f.drop('opp_team_r', axis=1, inplace=True)
#fixtures_f.drop('cur_team_r', axis=1, inplace=True)
#fixtures_f.drop('opp_team_r', axis=1, inplace=True)
#fixtures_f.drop('cur_p', axis=1, inplace=True)
#fixtures_f.drop('opp_p', axis=1, inplace=True)
#fixtures_f.drop('cur_post_r', axis=1, inplace=True)
#fixtures_f.drop('opp_post_r', axis=1, inplace=True)

fixtures_f['localteam_r'] = np.nan
fixtures_f['visitorteam_r'] = np.nan
fixtures_f['localteam_post_r'] = np.nan
fixtures_f['visitorteam_post_r'] = np.nan

# %%
fixtures_f['localteam_r'].isnull().sum()
# Out:
# 2028

# %%
def Probability(rating1, rating2):
    p1_w = 1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (rating2 - rating1) / 400))
    p2_w = 1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (rating1 - rating2) / 400))
 
    return p1_w, p2_w

def EloRating(Ra, Rb, K, d):

    # Calculate winning probabilities
    Pa, Pb = Probability(Ra, Rb)
 
    # Case -1 When Player A wins
    # Updating the Elo Ratings
    if (d == 1) :
        Ra = Ra + K * (1 - Pa)
        Rb = Rb + K * (0 - Pb)    
 
    # Case -2 When Player B wins
    # Updating the Elo Ratings
    elif (d == 0.5):
        Ra = Ra + K * (0.5 - Pa)
        Rb = Rb + K * (0.5 - Pb)
        
    else:
        Ra = Ra + K * (0 - Pa)
        Rb = Rb + K * (1 - Pb)   
    
    return Pa, Pb, Ra, Rb
     
    ##    print("Updated Ratings:-")
    ##    print("Ra =", round(Ra, 6)," Rb =", round(Rb, 6))

# %%
def test(data):
    K = 30
    
    nulls = data['localteam_r'].isnull().sum() + data['visitorteam_r'].isnull().sum()
    print(nulls)
    
    while nulls > 0:

        for index, row in data.iterrows():
            fixture_id = row['fixture_id']
            localteam_id = row['localteam_id']
            visitorteam_id = row['visitorteam_id']
            localteam_next = row['localteam_next']
            visitorteam_next = row['visitorteam_next']
            
#            if np.isnan(row['localteam_r']) == False & np.isnan(row['visitorteam_r']) == False & \
#                np.isnan(row['localteam_post_r']) == False & np.isnan(row['visitorteam_post_r']) == False:
#                return

            if (row['localteam_order'] == 1 & np.isnan(row['localteam_r'])) | (row['visitorteam_order'] == 1 & np.isnan(row['visitorteam_r'])):
                if row['localteam_order'] == 1 & np.isnan(row['localteam_r']):
                    data.loc[(data['fixture_id'] == fixture_id), 'localteam_r'] = 1500
                elif row['visitorteam_order'] == 1 & np.isnan(row['visitorteam_r']):
                    data.loc[(data['fixture_id'] == fixture_id), 'visitorteam_r'] = 1500
            
            elif np.isnan(row['localteam_r']) == False & np.isnan(row['visitorteam_r']) == False & \
                np.isnan(row['localteam_post_r']) & np.isnan(row['visitorteam_post_r']):
                    
                #print("evaluating fixture %d" % (fixture_id))
                
                #calculate ratings
                localteam_p, visitorteam_p, localteam_post_r, visitorteam_post_r = EloRating(row['localteam_r'], row['visitorteam_r'], K, row['outcome'])
                
                #assign probabilities for current game and post-game ratings
                data.loc[(data['fixture_id'] == fixture_id), 'localteam_p'] = localteam_p
                data.loc[(data['fixture_id'] == fixture_id), 'visitorteam_p'] = visitorteam_p
                data.loc[(data['fixture_id'] == fixture_id), 'localteam_post_r'] = localteam_post_r
                data.loc[(data['fixture_id'] == fixture_id), 'visitorteam_post_r'] = visitorteam_post_r
                
                #print('the localteam id is %d' % (localteam_id))
                #print('the visitorteam id is %d' % (visitorteam_id))
                
                #bring post-game ratings to next game
                if np.isnan(localteam_next) == False:    
                    l_next_localteam_id = data[data['fixture_id'] == localteam_next]['localteam_id'][0]
                    l_next_visitorteam_id = data[data['fixture_id'] == localteam_next]['visitorteam_id'][0]
                    
                    if localteam_id == 3444 | visitorteam_id == 3444:
                        print(fixture_id)
                        print(l_next_localteam_id)
                        print(l_next_visitorteam_id)
                        print(localteam_r)
                        print(visitorteam_r)
                    
                    if localteam_id == l_next_localteam_id:
                        data.loc[(data['fixture_id'] == localteam_next), 'localteam_r'] = localteam_post_r
                    else:
                        data.loc[(data['fixture_id'] == localteam_next), 'visitorteam_r'] = localteam_post_r
                    
                if np.isnan(visitorteam_next) == False:
                    v_next_localteam_id = data[data['fixture_id'] == visitorteam_next]['localteam_id'][0]
                    v_next_visitorteam_id = data[data['fixture_id'] == visitorteam_next]['visitorteam_id'][0]
                   
                    if visitorteam_id == v_next_localteam_id:
                        data.loc[(data['fixture_id'] == visitorteam_next), 'localteam_r'] = visitorteam_post_r
                    else:
                        data.loc[(data['fixture_id'] == visitorteam_next), 'visitorteam_r'] = visitorteam_post_r
                
                #print(l_next_localteam_id)
                #print(l_next_visitorteam_id)
                
        test(data)

# %%
test(fixtures_f)
# Out:
# 4056
# 3848
# 3796
# 3692
# 3612
# 3554
# 3506
# 3450
# 3408
# 3364
# 3328
# 3282
# 3235
# 3191
# 3153
# 3115
# 3079
# 3042
# 3012
# 2983
# 2952
# 2923
# 2889
# 2853
# 2813
# 2768
# 2729
# 2693
# 2660
# 2632
# 2599
# 2567
# 2540
# 2515
# 2491
# 2467
# 2443
# 2413
# 2383
# 2354
# 2329
# 2305
# 2277
# 2249
# 2224
# 2202
# 2178
# 2153
# 2123
# 2094
# 2064
# 2031
# 2005
# 1979
# 1958
# 1937
# 1913
# 1890
# 1868
# 1847
# 1821
# 1790
# 1748
# 1705
# 1660
# 1618
# 1585
# 1554
# 1527
# 1504
# 1484
# 1464
# 1437
# 1413
# 1383
# 1353
# 1322
# 1289
# 1257
# 1225
# 1193
# 1163
# 1127
# 1098
# 1066

# %%
fixtures_f[(fixtures_f['localteam_id']==3444) | (fixtures_f['visitorteam_id']==3444)].sort_values('starting_datetime')
# Out:
#       fixture_id  localteam_id      localteam_name  visitorteam_id  \
# 1905     1060581            34         Galatasaray            3444
# 1921     1060604          3444                FCSB              34
# 1944     1058982          3444                FCSB             503
# 1952     1059046           109          Fiorentina            3444
# 1967     1059172          3444                FCSB              79
# 1991     1059377            79  Olympique Lyonnais            3444
# 2000     1059448           503      Bayern München            3444
# 2017     1059605          3444                FCSB             109
# 648      1061742          3444                FCSB            5492
# 668      1061752          5492              Vardar            3444
# 676      1061298          3451      Dinamo Tbilisi            3444
# 691      1061309          3444                FCSB            3451
# 712      1061214          3444                FCSB             349
# 717      1061225           349      Legia Warszawa            3444
# 737      1059032            67          Schalke 04            3444
# 743      1059136          3444                FCSB              18
# 760      1059281          3444                FCSB             468
# 785      1059541           468               Basel            3444
# 790      1059626          3444                FCSB              67
# 814      1060995            18             Chelsea            3444
# 444      1061895           313        Strømsgodset            3444
# 460      1061904          3444                FCSB             313
# 466      1061338          2361              Aktobe            3444
# 487      1061348          3444                FCSB            2361
# 496      1061086          3444                FCSB            2742
# 511      1061096          2742          Ludogorets            3444
# 1277     1061789          2759             Trenčín            3444
# 1494     1061800          3444                FCSB            2759
# 1340     1061514          3444                FCSB            2736
# 1309     1061525          2736            Partizan            3444
# 142      1061445          2727        Sparta Praha            3444
# 159      1061456          3444                FCSB            2727
# 171      1061229          3444                FCSB               9
# 186      1061242             9     Manchester City            3444
# 1454     3239776          3444                FCSB            3545
# 1326     3239777          3545      Viktoria Plzeň            3444
# 1522     5402573            58         Sporting CP            3444
# 1217     5402574          3444                FCSB              58
#
#         visitorteam_name  localteam_score  visitorteam_score  \
# 1905                FCSB                2                  2
# 1921         Galatasaray                1                  0
# 1944      Bayern München                0                  1
# 1952                FCSB                0                  0
# 1967  Olympique Lyonnais                3                  5
# 1991                FCSB                2                  0
# 2000                FCSB                3                  0
# 2017          Fiorentina                0                  1
# 648               Vardar                3                  0
# 668                 FCSB                1                  2
# 676                 FCSB                0                  2
# 691       Dinamo Tbilisi                1                  1
# 712       Legia Warszawa                1                  1
# 717                 FCSB                2                  2
# 1905             1.0      1060604.0                1.0         1060604.0
# 1921             2.0      1058982.0                2.0         1058900.0
# 1944             3.0      1059046.0                1.0         1059038.0
# 1952             4.0      1059183.0                4.0         1059172.0
# 1967             5.0      1059377.0                5.0         1059377.0
# 1991             6.0      1059441.0                6.0         1059448.0
# 2000             5.0      1059622.0                7.0         1059605.0
# 2017             8.0      1061742.0                8.0         1059080.0
# 648              9.0      1061752.0                1.0         1061752.0
# 668              2.0      1061617.0               10.0         1061298.0
# 676              7.0      1061309.0               11.0         1061309.0
# 691             12.0      1061214.0                8.0         1061861.0
# 712             13.0      1061225.0                5.0         1061225.0
# 717              6.0      1061917.0               14.0         1059032.0
# 737             23.0      1059128.0               15.0         1059136.0
# 743             16.0      1059281.0               45.0         1059291.0
# 760             17.0      1059541.0               33.0         1059541.0
# 785             34.0      1059636.0               18.0         1059626.0
# 790             19.0      1060995.0               27.0         1060985.0
# 814             49.0      1058901.0               20.0         1061895.0
# 444              1.0      1061904.0               21.0         1061904.0
# 460             22.0      1061338.0                2.0               NaN
# 466             13.0      1061348.0               23.0         1061348.0
# 487             24.0      1061086.0               14.0               NaN
# 496             25.0      1061096.0               11.0         1061096.0
# 511             12.0      1058970.0               26.0         1061789.0
# 1277             1.0      1061800.0               27.0         1061800.0
# 1494            28.0      1061514.0                2.0         1062020.0
# 1340            29.0      1061525.0               35.0         1061525.0
# 1309            36.0      1061089.0               30.0         1061445.0
# 142             19.0      1061456.0               31.0         1061456.0
# 159             32.0      1061229.0               20.0               NaN
# 171             33.0      1061242.0               35.0         1061242.0
# 186             36.0      1059131.0               34.0         3239776.0
# 1454            35.0      3239777.0               31.0         3239777.0
# 1326            32.0            NaN               36.0         5402573.0
# 1522            25.0      5402574.0               37.0         5402574.0
# 1217            38.0            NaN               26.0         5932766.0
#
#       localteam_r  visitorteam_r  localteam_post_r  visitorteam_post_r  \
# 1905    1500.0000      1500.0000       1500.000000         1500.000000
# 1921    1500.0000      1500.0000       1515.000000         1485.000000
# 1944    1485.0000      1500.0000       1470.647200         1514.352800
# 1952    1514.3528      1470.6472       1512.475768         1472.524232
# 1967          NaN            NaN               NaN                 NaN
# 1991          NaN            NaN               NaN                 NaN
# 2000          NaN            NaN               NaN                 NaN
# 2017          NaN            NaN               NaN                 NaN
# 648           NaN      1500.0000               NaN                 NaN
# 668           NaN            NaN               NaN                 NaN
# 676           NaN            NaN               NaN                 NaN
# 691           NaN            NaN               NaN                 NaN
# 712           NaN            NaN               NaN                 NaN
# 717           NaN            NaN               NaN                 NaN
# 737           NaN            NaN               NaN                 NaN
# 743           NaN            NaN               NaN                 NaN
# 760           NaN            NaN               NaN                 NaN
# 785           NaN            NaN               NaN                 NaN
# 790           NaN            NaN               NaN                 NaN
# 814           NaN            NaN               NaN                 NaN
# 444     1500.0000            NaN               NaN                 NaN
# 460           NaN            NaN               NaN                 NaN
# 466           NaN            NaN               NaN                 NaN
# 487           NaN            NaN               NaN                 NaN
# 496           NaN            NaN               NaN                 NaN
# 511           NaN            NaN               NaN                 NaN
# 1277    1500.0000            NaN               NaN                 NaN
# 1494          NaN            NaN               NaN                 NaN
# 1340          NaN            NaN               NaN                 NaN
# 1309          NaN            NaN               NaN                 NaN
# 142           NaN            NaN               NaN                 NaN
# 159           NaN            NaN               NaN                 NaN
# 171           NaN            NaN               NaN                 NaN
# 186           NaN            NaN               NaN                 NaN
# 1454          NaN            NaN               NaN                 NaN
# 1326          NaN            NaN               NaN                 NaN
# 1522          NaN            NaN               NaN                 NaN
# 1217          NaN            NaN               NaN                 NaN
#
#       localteam_p  visitorteam_p
# 1905     0.500000       0.500000
# 1921     0.500000       0.500000
# 1944     0.478427       0.521573
# 1952     0.562568       0.437432
# 1967          NaN            NaN
# 1991          NaN            NaN
# 2000          NaN            NaN
# 2017          NaN            NaN
# 648           NaN            NaN
# 668           NaN            NaN
# 676           NaN            NaN
# 691           NaN            NaN
# 712           NaN            NaN
# 717           NaN            NaN
# 737           NaN            NaN
# 743           NaN            NaN
# 760           NaN            NaN
# 785           NaN            NaN
# 790           NaN            NaN
# 814           NaN            NaN
# 444           NaN            NaN
# 460           NaN            NaN
# 466           NaN            NaN
# 487           NaN            NaN
# 496           NaN            NaN
# 511           NaN            NaN
# 1277          NaN            NaN
# 1494          NaN            NaN
# 1340          NaN            NaN
# 1309          NaN            NaN
# 142           NaN            NaN
# 159           NaN            NaN
# 171           NaN            NaN
# 186           NaN            NaN
# 1454          NaN            NaN
# 1326          NaN            NaN
# 1522          NaN            NaN
# 1217          NaN            NaN
#
# [38 rows x 23 columns]

# %%
fixtures_f[(fixtures_f['localteam_order'] == 2) | (fixtures_f['visitorteam_order'] == 2)]
# Out:
#       fixture_id  localteam_id       localteam_name  visitorteam_id  \
# 3       10340559         10068         Newcastle FC          148038
# 7       10336090          2604                APOEL            5878
# 10      10336100           349       Legia Warszawa             326
# 34      10336112          6213             Zrinjski            3283
# 36      10336086           627              Sheriff            2671
# 103      1062118          5495            Alashkert            7058
# 125      1061893          6142              Liepāja              49
# 126      1061791           627              Sheriff             516
# 128      1061832           826                  SJK            3859
# 130      1061854          2673        Crvena Zvezda             147
# 132      1061974         11800              Mladost            2742
# 135      1061954          3603           Norrköping            1335
# 136      1062009           112          Ferencváros            5197
# 137      1062029          2759              Trenčín            1453
# 160      1061644            85            København            1094
# 165      1061517          2555           Anderlecht            6564
# 210      1059280            42       Leicester City             652
# 330      1059265           683  Borussia M'gladbach               9
# 426      1061948          5487              Banants            7058
# 427      1061968          4400              Levadia             847
# 428      1061985          8678                   HB           10068
# 449      1061597          5317              Qarabağ             147
# 454      1061786          1001             Žalgiris             674
# 456      1061828            53               Celtic            8673
# 460      1061904          3444                 FCSB             313
# 462      1061928          1260         St Patrick's             349
# 482      1061390          2963                Zenit             611
# 486      1061495           554             Beşiktaş              73
# 488      1061432            85            København           12582
# 509      1061159         13258        Athletic Club             597
# ...          ...           ...                  ...             ...
# 1886     1061265         11333               Kaunas              62
# 1887     1061233          3859                 BATE            2555
# 1888     1061285          3451       Dinamo Tbilisi              57
# 1889     1061113           556          Dynamo Kyiv            1152
# 1890     1061248          3678           Rapid Wien             272
# 1891     1061165          7288                  NaN            1020
# 34          10364237.0          NaN            NaN               NaN
# 36                 NaN          NaN            NaN               NaN
# 103          1818602.0          NaN            NaN               NaN
# 125          1061486.0          NaN            NaN               NaN
# 126          1061695.0          NaN            NaN               NaN
# 128          1061424.0          NaN            NaN               NaN
# 130         10336103.0          NaN            NaN               NaN
# 132          1061400.0          NaN            NaN               NaN
# 135          1061611.0          NaN            NaN               NaN
# 136          1061486.0  1500.000000    1500.000000       1500.000000
# 137         10336091.0          NaN            NaN               NaN
# 160                NaN          NaN            NaN               NaN
# 165          1061252.0          NaN            NaN               NaN
# 210          1059447.0          NaN            NaN               NaN
# 330          1059439.0          NaN            NaN               NaN
# 426          1061691.0          NaN            NaN               NaN
# 427          1818604.0          NaN            NaN               NaN
# 428          1061970.0          NaN            NaN               NaN
# 449          1062087.0          NaN            NaN               NaN
# 454          1061527.0          NaN            NaN               NaN
# 456                NaN          NaN            NaN               NaN
# 460                NaN          NaN            NaN               NaN
# 462          1061567.0          NaN            NaN               NaN
# 482                NaN          NaN            NaN               NaN
# 486          5932769.0          NaN            NaN               NaN
# 488                NaN          NaN            NaN               NaN
# 509          1059077.0          NaN            NaN               NaN
# ...                ...          ...            ...               ...
# 1886         1059050.0  1526.251479    1473.748521       1539.001842
# 1887         1061228.0          NaN            NaN               NaN
# 1888         1060628.0          NaN            NaN               NaN
# 1889               NaN          NaN            NaN               NaN
# 1890         1060513.0          NaN            NaN               NaN
# 1891         1060543.0  1457.528606    1513.763389       1444.935475
# 1893         1061603.0  1513.819563    1486.180437       1527.628797
# 1894               NaN  1501.236611    1527.471394       1517.367110
# 1895               NaN  1485.000000    1515.000000       1501.291995
# 1896         1060989.0          NaN            NaN               NaN
# 1898         1061579.0          NaN            NaN               NaN
# 1916         1058947.0          NaN            NaN               NaN
# 1918         1061643.0          NaN            NaN               NaN
# 1920         1059075.0          NaN            NaN               NaN
# 1921         1058900.0  1500.000000    1500.000000       1515.000000
# 1923               NaN  1516.617936    1500.749175       1530.933302
# 1924         1058991.0          NaN            NaN               NaN
# 1925         1058895.0  1523.443074    1516.726577       1508.153136
# 1927               NaN          NaN            NaN               NaN
# 1928         1058972.0  1485.000000    1515.000000       1486.291995
# 1929         1061459.0          NaN            NaN               NaN
# 1930         1059018.0          NaN            NaN               NaN
# 1947         1059149.0          NaN            NaN               NaN
# 1951         1059172.0          NaN            NaN               NaN
# 1953         1059193.0          NaN            NaN               NaN
# 1955         1059211.0          NaN            NaN               NaN
# 1957         1059227.0          NaN            NaN               NaN
# 1958         1059245.0          NaN            NaN               NaN
# 1960         1059261.0          NaN            NaN               NaN
# 1961         1059261.0          NaN            NaN               NaN
#
#       visitorteam_post_r  localteam_p  visitorteam_p
# 3                    NaN          NaN            NaN
# 7                    NaN          NaN            NaN
# 10                   NaN          NaN            NaN
# 34                   NaN          NaN            NaN
# 36                   NaN          NaN            NaN
# 103                  NaN          NaN            NaN
# 125                  NaN          NaN            NaN
# 126                  NaN          NaN            NaN
# 128                  NaN          NaN            NaN
# 130                  NaN          NaN            NaN
# 132                  NaN          NaN            NaN
# 135                  NaN          NaN            NaN
# 136          1500.000000     0.500000       0.500000
# 137                  NaN          NaN            NaN
# 160                  NaN          NaN            NaN
# 165                  NaN          NaN            NaN
# 210                  NaN          NaN            NaN
# 330                  NaN          NaN            NaN
# 426                  NaN          NaN            NaN
# 427                  NaN          NaN            NaN
# 428                  NaN          NaN            NaN
# 449                  NaN          NaN            NaN
# 454                  NaN          NaN            NaN
# 456                  NaN          NaN            NaN
# 460                  NaN          NaN            NaN
# 462                  NaN          NaN            NaN
# 482                  NaN          NaN            NaN
# 486                  NaN          NaN            NaN
# 488                  NaN          NaN            NaN
# 509                  NaN          NaN            NaN
# ...                  ...          ...            ...
# 1886         1460.998158     0.574988       0.425012
# 1887                 NaN          NaN            NaN
# 1888                 NaN          NaN            NaN
# 1889                 NaN          NaN            NaN
# 1890                 NaN          NaN            NaN
# 1891         1526.356520     0.419771       0.580229
# 1893         1472.371203     0.539692       0.460308
# 1894         1511.340895     0.462317       0.537683
# 1895         1498.708005     0.456934       0.543066
# 1896                 NaN          NaN            NaN
# 1898                 NaN          NaN            NaN
# 1916                 NaN          NaN            NaN
# 1918                 NaN          NaN            NaN
# 1920                 NaN          NaN            NaN
# 1921         1485.000000     0.500000       0.500000
# 1923         1486.433808     0.522821       0.477179
# 1924                 NaN          NaN            NaN
# 1925         1532.016515     0.509665       0.490335
# 1927                 NaN          NaN            NaN
# 1928         1513.708005     0.456934       0.543066
# 1929                 NaN          NaN            NaN
# 1930                 NaN          NaN            NaN
# 1947                 NaN          NaN            NaN
# 1951                 NaN          NaN            NaN
# 1953                 NaN          NaN            NaN
# 1955                 NaN          NaN            NaN
# 1957                 NaN          NaN            NaN
# 1958                 NaN          NaN            NaN
# 1960                 NaN          NaN            NaN
# 1961                 NaN          NaN            NaN
#
# [209 rows x 23 columns]

# %%
fixtures_f[(fixtures_f['localteam_id']==7058) | (fixtures_f['visitorteam_id']==7058)].sort_values('starting_datetime')
# Out:
#       fixture_id  localteam_id    localteam_name  visitorteam_id  \
# 1851     1061438          7058   FC Santa Coloma           11333
# 1859     1061447         11333            Kaunas            7058
# 1063     1061926          7058   FC Santa Coloma            1877
# 1065     1061927          1877        Birkirkara            7058
# 850      1061935          7058   FC Santa Coloma            1401
# 852      1061945          1401     F91 Dudelange            7058
# 423       207684          7058   FC Santa Coloma            5487
# 426      1061948          5487           Banants            7058
# 434      1061691          7058   FC Santa Coloma            2997
# 450      1061702          2997  Maccabi Tel Aviv            7058
# 1396     1061970         10068      Newcastle FC            7058
# 1505     1061980          7058   FC Santa Coloma           10068
# 314      1062109          7058   FC Santa Coloma            5495
# 103      1062118          5495         Alashkert            7058
# 1445     1818602          5495         Alashkert            7058
# 1555     1818653          7058   FC Santa Coloma            5495
# 0       10332447          7058   FC Santa Coloma          148038
#
#       visitorteam_name  localteam_score  visitorteam_score  \
# 1851            Kaunas                1                  4
# 1859   FC Santa Coloma                3                  1
# 1063        Birkirkara                0                  3
# 1065   FC Santa Coloma                4                  3
# 850      F91 Dudelange                0                  2
# 852    FC Santa Coloma                2                  0
# 423            Banants                1                  0
# 426    FC Santa Coloma                3                  2
# 434   Maccabi Tel Aviv                0                  1
# 450    FC Santa Coloma                2                  0
# 1396   FC Santa Coloma                0                  0
# 1505      Newcastle FC                1                  2
# 314          Alashkert                0                  0
# 103    FC Santa Coloma                3                  0
# 1445   FC Santa Coloma                1                  0
# 1555         Alashkert                1                  1
# 0                Drita                0                  0
#
#         starting_datetime       league_name country_name      ...        \
# 1851  2008-07-15 18:30:00  Champions League    Lithuania      ...
# 1859  2008-07-22 16:30:00  Champions League      Andorra      ...
# 1063  2010-06-29 17:00:00  Champions League        Malta      ...
# 1065  2010-07-06 16:00:00  Champions League      Andorra      ...
# 850   2011-06-28 17:00:00  Champions League   Luxembourg      ...
# 852   2011-07-05 16:30:00  Champions League      Andorra      ...
# 423   2014-07-01 18:00:00  Champions League      Armenia      ...
# 426   2014-07-08 14:00:00  Champions League      Andorra      ...
# 434   2014-07-15 18:00:00  Champions League       Israel      ...
# 450   2014-07-22 17:30:00  Champions League      Andorra      ...
# 1396  2015-06-30 18:00:00  Champions League      Andorra      ...
# 1505  2015-07-07 18:00:00  Champions League    Gibraltar      ...
# 314   2016-06-28 18:00:00  Champions League      Armenia      ...
# 103   2016-07-05 15:00:00  Champions League      Andorra      ...
# 1445  2017-06-27 19:00:00  Champions League      Andorra      ...
# 1555  2017-07-04 21:30:00  Champions League      Armenia      ...
# 0     2018-06-26 15:00:00  Champions League       Kosovo      ...
#
#      localteam_order localteam_next  visitorteam_order  visitorteam_next  \
# 1851             1.0      1061447.0                1.0         1061447.0
# 1859             2.0      1061258.0                2.0         1061926.0
# 1063             3.0      1061927.0                1.0         1061927.0
# 1065             2.0      1061620.0                4.0         1061935.0
# 850              5.0      1061945.0                5.0         1061945.0
# 852              6.0      1061625.0                6.0          207684.0
# 423              7.0      1061948.0                1.0         1061948.0
# 426              2.0            NaN                8.0         1061691.0
# 434              9.0      1061702.0                5.0         1061702.0
# 450              6.0      1061545.0               10.0         1061970.0
# 1396             3.0      1061980.0               11.0         1061980.0
# 1505            12.0      1062109.0                4.0         1061638.0
# 314             13.0      1062118.0                1.0         1062118.0
# 103              2.0      1061737.0               14.0         1818602.0
# 1445             5.0      1818653.0               15.0         1818653.0
# 1555            16.0     10332447.0                6.0         2457398.0
# 0               17.0            NaN                1.0        10340559.0
#
#       localteam_r  visitorteam_r  localteam_post_r  visitorteam_post_r  \
# 1851       1500.0         1500.0       1485.000000         1515.000000
# 1859       1515.0         1485.0       1528.708005         1471.291995
# 1063          NaN         1500.0               NaN                 NaN
# 1065          NaN            NaN               NaN                 NaN
# 850           NaN            NaN               NaN                 NaN
# 852           NaN            NaN               NaN                 NaN
# 423           NaN         1500.0               NaN                 NaN
# 426           NaN            NaN               NaN                 NaN
# 434           NaN            NaN               NaN                 NaN
# 450           NaN            NaN               NaN                 NaN
# 1396          NaN            NaN               NaN                 NaN
# 1505          NaN            NaN               NaN                 NaN
# 314           NaN         1500.0               NaN                 NaN
# 103           NaN            NaN               NaN                 NaN
# 1445          NaN            NaN               NaN                 NaN
# 1555          NaN            NaN               NaN                 NaN
# 0             NaN         1500.0               NaN                 NaN
#
#       localteam_p  visitorteam_p
# 1851     0.500000       0.500000
# 1859     0.543066       0.456934
# 1063          NaN            NaN
# 1065          NaN            NaN
# 850           NaN            NaN
# 852           NaN            NaN
# 423           NaN            NaN
# 426           NaN            NaN
# 434           NaN            NaN
# 450           NaN            NaN
# 1396          NaN            NaN
# 1505          NaN            NaN
# 314           NaN            NaN
# 103           NaN            NaN
# 1445          NaN            NaN
# 1555          NaN            NaN
# 0             NaN            NaN
#
# [17 rows x 23 columns]

# %%
combined_fixtures_f[(combined_fixtures_f['cur_team_id'] == 8) & (combined_fixtures_f['opp_team_id'] == 2930)]
# Out:
#      index  cur_team_id  cur_team_score  fixture_id  opp_team_id  \
# 26  905229          8.0               2     1058774       2930.0
# 27  910518          8.0               1     1058782       2930.0
#
#     opp_team_score    starting_datetime  cur_team_order  cur_team_next  \
# 26               0  2008-02-19 19:45:00             1.0      1058782.0
# 27               0  2008-03-11 19:45:00             2.0      1058515.0
#
#     outcome  opp_team_order  opp_team_next  cur_team_r  opp_team_r     cur_p  \
# 26      1.0             1.0      1058782.0      1500.0      1500.0  0.500000
# 27      1.0             2.0      1058914.0      1515.0      1485.0  0.456934
#
#        opp_p   cur_post_r   opp_post_r
# 26  0.500000  1515.000000  1485.000000
# 27  0.543066  1501.291995  1498.708005

# %%
combined_fixtures_f[combined_fixtures_f['cur_team_id'] == 8]
# Out:
#      index  cur_team_id  cur_team_score  fixture_id  opp_team_id  \
# 26  905229          8.0               2     1058774       2930.0
# 27  910518          8.0               1     1058782       2930.0
# 28  916511          8.0               1     1058515         19.0
# 29  918441          8.0               4     1058523         19.0
# 30  922762          8.0               1     1058448         18.0
# 31  925006          8.0               2     1058452         18.0
# 32  940076          8.0               0     1061006        700.0
# 33  943808          8.0               1     1061013        700.0
# 34  949956          8.0               2     1058872         44.0
# 35  954996          8.0               3     1059078        682.0
# 36  961191          8.0               1     1059219       7980.0
# 37  965649          8.0               1     1059287       7980.0
# 38  971705          8.0               1     1059475         44.0
# 39  974743          8.0               3     1059540        682.0
# 40  819983          8.0               1     1058802       3468.0
# 41  823975          8.0               4     1058809       3468.0
# 42  833058          8.0               1     1058527         18.0
# 43  835387          8.0               4     1058534         18.0
# 44  869723          8.0               1     1059090        396.0
# 45  874501          8.0               0     1059171        109.0
# 46  880956          8.0               1     1059326         79.0
# 47  885629          8.0               1     1059543         79.0
# 48  890866          8.0               1     1059635        396.0
# 49  894167          8.0               1     1060977        109.0
# 50  259618          8.0               2     1058970       2742.0
# 51  266165          8.0               0     1059225        468.0
# 52  274333          8.0               0     1059400       3468.0
# 53  279950          8.0               0     1059496       3468.0
# 54  286809          8.0               2     1060506       2742.0
# 55  290856          8.0               1     1060660        468.0
# 56  753628          8.0               2     5402571       2726.0
# 57  595372          8.0               4     5402572       2726.0
# 58  697373          8.0               2     5932768        676.0
# 59   17131          8.0               1     5932776       2712.0
# 60  627546          8.0               7     5932792       2973.0
# 61  666805          8.0               3     5932816       2973.0
# 62  685658          8.0               3     5932824        676.0
# 63  760978          8.0               7     5932848       2712.0
# 27      1.0             2.0      1058914.0  1515.000000      1485.0  0.456934
# 28      0.5             3.0      1058523.0  1501.291995      1515.0       NaN
# 29      1.0             4.0      1060972.0          NaN         NaN       NaN
# 30      0.5             5.0      1058452.0          NaN         NaN       NaN
# 31      0.0             6.0      1058434.0          NaN         NaN       NaN
# 32      0.5             1.0      1061013.0          NaN      1500.0       NaN
# 33      1.0             2.0      1059018.0          NaN         NaN       NaN
# 34      1.0             3.0      1059070.0          NaN         NaN       NaN
# 35      1.0             2.0      1059211.0          NaN         NaN       NaN
# 36      0.5             5.0      1059287.0          NaN         NaN       NaN
# 37      0.5             6.0      1059481.0          NaN         NaN       NaN
# 38      1.0             7.0      1058958.0          NaN         NaN       NaN
# 39      1.0             6.0      1061449.0          NaN         NaN       NaN
# 40      1.0             9.0      1058809.0          NaN         NaN       NaN
# 41      1.0            10.0      1058967.0          NaN         NaN       NaN
# 42      0.0            16.0      1058534.0          NaN         NaN       NaN
# 43      0.5            17.0      1058450.0          NaN         NaN       NaN
# 44      1.0             7.0      1059161.0          NaN         NaN       NaN
# 45      0.0            10.0      1059337.0          NaN         NaN       NaN
# 46      0.0            15.0      1059543.0          NaN         NaN       NaN
# 47      0.5            16.0      1059625.0          NaN         NaN       NaN
# 48      1.0            11.0      1060832.0          NaN         NaN       NaN
# 49      0.0            14.0      1058812.0          NaN         NaN       NaN
# 50      1.0            13.0      1059236.0          NaN         NaN       NaN
# 51      0.0            38.0      1059390.0          NaN         NaN       NaN
# 52      0.0            58.0      1059496.0          NaN         NaN       NaN
# 53      0.0            59.0      1060516.0          NaN         NaN       NaN
# 54      0.5            17.0      1060689.0          NaN         NaN       NaN
# 55      0.5            42.0      1058844.0          NaN         NaN       NaN
# 56      1.0             1.0      5402572.0          NaN      1500.0       NaN
# 57      1.0             2.0            NaN          NaN         NaN       NaN
# 58      0.5            29.0      5932775.0          NaN         NaN       NaN
# 59      0.5            10.0      5932791.0          NaN         NaN       NaN
# 60      1.0            37.0      5932816.0          NaN         NaN       NaN
# 61      1.0            38.0      5932823.0          NaN         NaN       NaN
# 62      0.5            33.0      5932847.0          NaN         NaN       NaN
# 63      1.0            14.0     10405611.0          NaN         NaN       NaN
# 64      1.0            69.0      8801070.0          NaN         NaN       NaN
# 65      0.5            70.0            NaN          NaN         NaN       NaN
# 66      1.0            53.0     10306071.0          NaN         NaN       NaN
# 67      1.0            54.0            NaN          NaN         NaN       NaN
# 68      1.0            47.0     10321504.0          NaN         NaN       NaN
# 69      0.0            48.0            NaN          NaN         NaN       NaN
# 70      0.0           106.0            NaN          NaN         NaN       NaN
#
#        opp_p   cur_post_r   opp_post_r
# 26  0.500000  1515.000000  1485.000000
# 27  0.543066  1501.291995  1498.708005
# 28       NaN          NaN          NaN
# 29       NaN          NaN          NaN
# 30       NaN          NaN          NaN
# 31       NaN          NaN          NaN
# 32       NaN          NaN          NaN
# 33       NaN          NaN          NaN
# 34       NaN          NaN          NaN
# 35       NaN          NaN          NaN
# 36       NaN          NaN          NaN
# 37       NaN          NaN          NaN
# 38       NaN          NaN          NaN
# 39       NaN          NaN          NaN
# 40       NaN          NaN          NaN
# 41       NaN          NaN          NaN
# 42       NaN          NaN          NaN
# 43       NaN          NaN          NaN
# 44       NaN          NaN          NaN
# 45       NaN          NaN          NaN
# 46       NaN          NaN          NaN
# 47       NaN          NaN          NaN
# 48       NaN          NaN          NaN
# 49       NaN          NaN          NaN
# 50       NaN          NaN          NaN
# 51       NaN          NaN          NaN
# 52       NaN          NaN          NaN
# 53       NaN          NaN          NaN
# 54       NaN          NaN          NaN
# 55       NaN          NaN          NaN
# 56       NaN          NaN          NaN
# 57       NaN          NaN          NaN
# 58       NaN          NaN          NaN
# 59       NaN          NaN          NaN
# 60       NaN          NaN          NaN
# 61       NaN          NaN          NaN
# 62       NaN          NaN          NaN
# 63       NaN          NaN          NaN
# 64       NaN          NaN          NaN
# 65       NaN          NaN          NaN
# 66       NaN          NaN          NaN
# 67       NaN          NaN          NaN
# 68       NaN          NaN          NaN
# 69       NaN          NaN          NaN
# 70       NaN          NaN          NaN

# %%
#dupes = combined_fixtures[(combined_fixtures['fixture_order'] - combined_fixtures['fixture_order'].apply(np.floor)) > 0].sort_values('starting_datetime')`b
#dupes.to_csv('duplicate_fixtures')

# %%
fixtures = pd.merge(fixtures, combined_fixtures[['fixture_order', 'fixture_id', 'team_id']],\
                    how='left', left_on=['localteam_id','fixture_id'], right_on = ['team_id','fixture_id'])\
                .drop(['team_id'], axis=1)\
                .rename(index=str, columns={'fixture_order': 'localteam_order'})

# %%
fixtures = pd.merge(fixtures, combined_fixtures[['fixture_order', 'fixture_id', 'team_id']],\
                    how='left', left_on=['visitorteam_id','fixture_id'], right_on = ['team_id','fixture_id'])\
                .drop(['team_id'], axis=1)\
                .rename(index=str, columns={'fixture_order': 'visitorteam_order'})

# %%
fixtures = fixtures.sort_values('starting_datetime')

# %%
#assign initial rating to first game played by all teams
fixtures['localteam_rating'] = np.where(fixtures['localteam_order'] == 1, 1500, np.nan)
fixtures['visitorteam_rating'] = np.where(fixtures['visitorteam_order'] == 1, 1500, np.nan)

# %%
fixtures.head()
# Out:
#         fixture_id localteam_id   localteam_name visitorteam_id  \
# 906067       22909           50   Torquay United            185
# 906074      654189         1244          DPMM FC           3347
# 906073      654188         1908  Negeri Sembilan           2276
# 906072      654187         3446            Perak           3398
# 906068        5881           11           Fulham             18
#
#           visitorteam_name  localteam_score  visitorteam_score  \
# 906067         Exeter City                1                  0
# 906074               Kedah                2                  0
# 906073  Johor Darul Ta'zim                2                  0
# 906072             Sarawak                5                  0
# 906068             Chelsea                1                  2
#
#           starting_datetime               league_name country_name  \
# 906067  2008-01-01 12:00:00  Vanarama National League      England
# 906074  2008-01-01 12:45:00              Super League     Malaysia
# 906073  2008-01-01 12:45:00              Super League     Malaysia
# 906072  2008-01-01 12:45:00              Super League     Malaysia
# 906068  2008-01-01 12:45:00            Premier League      England
#
#               fifa_name season_name  outcome  localteam_order  \
# 906067  ENG,NIR,SCO,WAL   2007/2008      1.0              1.0
# 906074              MAS   2007/2008      1.0              1.0
# 906073              MAS   2007/2008      1.0              1.0
# 906072              MAS   2007/2008      1.0              1.0
# 906068  ENG,NIR,SCO,WAL   2007/2008      0.0              1.0
#
#         visitorteam_order  localteam_rating  visitorteam_rating
# 906067                1.0            1500.0              1500.0
# 906074                1.0            1500.0              1500.0
# 906073                1.0            1500.0              1500.0
# 906072                1.0            1500.0              1500.0
# 906068                1.0            1500.0              1500.0

# %%
def Probability(rating1, rating2):
 
    return 1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (rating1 - rating2) / 400))

# %%
def EloRating(Ra, Rb, K, d):

    # To calculate the Winning
    # Probability of Player A
    Pa = Probability(Rb, Ra)
 
    # To calculate the Winning
    # Probability of Player B
    Pb = Probability(Ra, Rb)
 
    # Case -1 When Player A wins
    # Updating the Elo Ratings
    if (d == 1) :
        Ra = Ra + K * (1 - Pa)
        Rb = Rb + K * (0 - Pb)
     
 
    # Case -2 When Player B wins
    # Updating the Elo Ratings
    else :
        Ra = Ra + K * (0 - Pa)
        Rb = Rb + K * (1 - Pb)
    
    return localteam_rating_post=Ra, visitorteam_rating_post=Rb
     
    ##    print("Updated Ratings:-")
    ##    print("Ra =", round(Ra, 6)," Rb =", round(Rb, 6))

# %%
test = fixtures[(fixtures['localteam_order'] == 1) & (fixtures['visitorteam_order'] == 1)]

# %%
test.apply(EloRating(test['localteam_rating'], test['visitorteam_rating'], 30, test['outcome']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-640791707e23> in <module>()
# ----> 1 test.apply(EloRating(test['localteam_rating'], test['visitorteam_rating'], 30, test['outcome']))
#
# <ipython-input-109-736e77a8c0ca> in EloRating(Ra, Rb, K, d)
#       3     # To calculate the Winning
#       4     # Probability of Player A
# ----> 5     Pa = Probability(Rb, Ra)
#       6
#       7     # To calculate the Winning
#
# <ipython-input-108-ff8abcfd61a2> in Probability(rating1, rating2)
#       1 def Probability(rating1, rating2):
#       2
# ----> 3     return 1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (rating1 - rating2) / 400))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>

# %%
test_onerow = test[0:1]

# %%
Probability(test_onerow['localteam_rating'], test_onerow['visitorteam_rating'])
# Out:
# 0.5

# %%
test['p_localteam'] = test[['fixture_id', 'visitorteam_rating', 'localteam_rating']].apply(Probability)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-c2095af8cba2> in <module>()
# ----> 1 test['p_localteam'] = test[['fixture_id', 'visitorteam_rating', 'localteam_rating']].apply(Probability)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# TypeError: ("Probability() missing 1 required positional argument: 'rating2'", 'occurred at index fixture_id')

# %%
def elo(data
# rank fixtures played by each team
    
# calcul


# Function to calculate the Probability
def Probability(rating1, rating2):
 
    return 1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (rating1 - rating2) / 400))
 
 
# Function to calculate Elo rating
# K is a constant.
# d determines whether
# Player A wins or Player B. 

def EloRating(Ra, Rb, K, d):

    # To calculate the Winning
    # Probability of Player A
    Pa = Probability(Rb, Ra)
 
    # To calculate the Winning
    # Probability of Player B
    Pb = Probability(Ra, Rb)
 
    # Case -1 When Player A wins
    # Updating the Elo Ratings
    if (d == 1) :
        Ra = Ra + K * (1 - Pa)
        Rb = Rb + K * (0 - Pb)
     
 
    # Case -2 When Player B wins
    # Updating the Elo Ratings
    else :
        Ra = Ra + K * (0 - Pa)
        Rb = Rb + K * (1 - Pb)
     
 
    print("Updated Ratings:-")
    print("Ra =", round(Ra, 6)," Rb =", round(Rb, 6))
 
# Driver code
 
# Ra and Rb are current ELO ratings
Ra = 1200
Rb = 1000
K = 30
d = 1
EloRating(Ra, Rb, K, d)
 
# This code is contributed by
# Smitha Dinesh Semwal
